# %%
from ultralytics import YOLO

# %%
# Load a YOLO model trained for pose estimation
model = YOLO("yolov8l-pose.pt")

# Run inference on an image
results = model("sample_image.png", show=False, save=False)

# Extract keypoints from results
for result in results:
    keypoints = result.keypoints  # Keypoints are stored as a tensor
    print(keypoints.shape)
    keypoints_array = keypoints.numpy()  # Convert to NumPy array for easier manipulation
    # print(keypoints_array.data)
# Out:
# image 1/1 c:\Users\Jackson Montour\Documents\GitHub\DeepSwing\sample_image.png: 640x576 1 person, 514.7ms
# Speed: 3.0ms preprocess, 514.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
# torch.Size([1, 17, 3])

# %%
import cv2

# Load the YOLOv8 Pose Model
model = YOLO("yolov8l-pose.pt")  # You can use 'yolov8s-pose.pt' for better accuracy

# Load Video
input_video_path = "sample_video.mp4"  # Change this to your video file path
output_video_path = "output_sample.mp4"

# Open the video file
cap = cv2.VideoCapture(input_video_path)
fps = int(cap.get(cv2.CAP_PROP_FPS))  # Get FPS of the input video
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define a VideoWriter to save the output
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # Codec
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Process Each Frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Exit loop if no more frames

    # Run YOLO Pose Estimation on Frame
    results = model(frame)

    # Visualize Pose Results
    annotated_frame = results[0].plot()  # Overlayed frame with pose keypoints

    # Write the processed frame to output video
    out.write(annotated_frame)

    # Optional: Display frame (Press 'q' to quit)
    # cv2.imshow("Pose Estimation", annotated_frame)
    # if cv2.waitKey(1) & 0xFF == ord("q"):
    #     break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processed video saved to {output_video_path}")
# Out:
# 0: 640x512 1 person, 619.9ms
# Speed: 4.2ms preprocess, 619.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 589.8ms
# Speed: 2.4ms preprocess, 589.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 553.5ms
# Speed: 2.2ms preprocess, 553.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 527.2ms
# Speed: 2.3ms preprocess, 527.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 582.1ms
# Speed: 1.8ms preprocess, 582.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 526.9ms
# Speed: 2.4ms preprocess, 526.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 532.8ms
# Speed: 2.4ms preprocess, 532.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 509.9ms
# Speed: 1.7ms preprocess, 509.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 519.0ms
# Speed: 1.7ms preprocess, 519.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 600.4ms
# Speed: 2.2ms preprocess, 600.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 543.0ms
# Speed: 1.9ms preprocess, 543.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 549.6ms
# Speed: 2.5ms preprocess, 549.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 541.6ms
# Speed: 2.0ms preprocess, 541.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 468.5ms
# Speed: 2.0ms preprocess, 468.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 495.2ms
# Speed: 2.1ms preprocess, 495.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 493.7ms
# Speed: 1.9ms preprocess, 493.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 488.9ms
# Speed: 1.7ms preprocess, 488.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 475.0ms
# Speed: 1.5ms preprocess, 475.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 475.8ms
# Speed: 1.8ms preprocess, 475.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 544.0ms
# Speed: 2.0ms preprocess, 544.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 467.4ms
# Speed: 3.0ms preprocess, 467.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 473.5ms
# Speed: 1.7ms preprocess, 473.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 481.0ms
# Speed: 1.8ms preprocess, 481.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 473.1ms
# Speed: 1.6ms preprocess, 473.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 480.1ms
# Speed: 1.6ms preprocess, 480.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person,