# %%
from ultralytics import YOLO

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.6.0+cu126
# True

# %%
import cv2

# Load the YOLOv8 Pose Model
model = YOLO("models/yolo11l-pose.pt")

# Load Video
input_video_path = "data/sample_video.mp4"
output_video_path = "outputs/test.mp4"

# Open the video file
cap = cv2.VideoCapture(input_video_path)
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define a VideoWriter to save the output
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # Codec
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

xy_list = []
xyn_list = []

# Process Each Frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Exit loop if no more frames

    # Run YOLO Pose Estimation on Frame
    results = model(frame)
    # Access the results
    for result in results:
        xy = result.keypoints.xy  # x and y coordinates
        xyn = result.keypoints.xyn  # normalized

        xy_list.append(xy)
        xyn_list.append(xyn)

    # Visualize Pose Results
    annotated_frame = results[0].plot()  # Overlayed frame with pose keypoints

    # Write the processed frame to output video
    out.write(annotated_frame)

    # Optional: Display frame (Press 'q' to quit)
    # cv2.imshow("Pose Estimation", annotated_frame)
    # if cv2.waitKey(1) & 0xFF == ord("q"):
    #     break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processed video saved to {output_video_path}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x-pose.pt to 'models\yolo11x-pose.pt'...
# 100%|██████████| 113M/113M [00:02<00:00, 44.6MB/s]
# 0: 640x480 1 person, 69.4ms
# Speed: 2.7ms preprocess, 69.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 3.6ms preprocess, 49.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.3ms
# Speed: 2.2ms preprocess, 48.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.1ms
# Speed: 2.2ms preprocess, 48.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.0ms
# Speed: 3.2ms preprocess, 49.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 2.2ms preprocess, 49.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.8ms
# Speed: 2.3ms preprocess, 49.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.7ms
# Speed: 2.6ms preprocess, 48.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.7ms
# Speed: 2.3ms preprocess, 49.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.2ms
# Speed: 2.5ms preprocess, 49.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 2.9ms preprocess, 49.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.0ms
# Speed: 2.2ms preprocess, 50.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.1ms
# Speed: 2.3ms preprocess, 49.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.3ms
# Speed: 1.9ms preprocess, 50.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.9ms
# Speed: 2.2ms preprocess, 48.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.7ms
# Speed: 2.0ms preprocess, 49.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.2ms
# Speed: 2.1ms preprocess, 50.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.5ms
# Speed: 1.9ms preprocess, 49.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 2.7ms preprocess, 49.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.7ms
# Speed: 1.8ms preprocess, 49.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 1.9ms preprocess, 49.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.8ms
# Speed: 2.8ms preprocess, 48.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.6ms
# Speed: 2.2ms preprocess, 48.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.9ms
# Speed: 1.8ms preprocess, 48.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.5ms
# Speed: 2.0ms preprocess, 49.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.0ms
# Speed: 2.3ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.8ms
# Speed: 2.1ms preprocess, 48.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.1ms
# Speed: 2.5ms preprocess, 50.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.9ms
# Speed: 2.0ms preprocess, 48.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.6ms
# Speed: 2.7ms preprocess, 49.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.4ms
# Speed: 1.8ms preprocess, 50.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.7ms
# Speed: 1.9ms preprocess, 48.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.0ms
# Speed: 2.1ms preprocess, 50.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.0ms
# Speed: 2.1ms preprocess, 50.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 51.0ms
# Speed: 2.1ms preprocess, 51.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.1ms
# Speed: 2.3ms preprocess, 49.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.1ms
# Speed: 2.3ms preprocess, 50.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 2.5ms preprocess, 49.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 2.0ms preprocess, 49.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 2.2ms preprocess, 49.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.6ms
# Speed: 2.7ms preprocess, 49.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.4ms
# Speed: 2.2ms preprocess, 49.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.4ms
# Speed: 2.4ms preprocess, 49.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.9ms
# Speed: 2.6ms preprocess, 49.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.9ms
# Speed: 2.1ms preprocess, 48.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.1ms
# Speed: 1.9ms preprocess, 50.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.0ms
# Speed: 2.4ms preprocess, 49.0ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.2ms
# Speed: 2.2ms preprocess, 50.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.2ms
# Speed: 2.1ms preprocess, 49.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.5ms
# Speed: 2.2ms preprocess, 49.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.9ms
# Speed: 2.2ms preprocess, 50.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.9ms
# Speed: 2.5ms preprocess, 49.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 51.7ms
# Speed: 2.1ms preprocess, 51.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.4ms
# Speed: 1.9ms preprocess, 50.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.4ms
# Speed: 2.0ms preprocess, 50.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.6ms
# Speed: 2.7ms preprocess, 49.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.6ms
# Speed: 2.0ms preprocess, 49.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.1ms
# Speed: 3.2ms preprocess, 50.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.2ms
# Speed: 1.9ms preprocess, 49.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.0ms
# Speed: 1.9ms preprocess, 50.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.4ms
# Speed: 2.4ms preprocess, 50.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.1ms
# Speed: 1.9ms preprocess, 50.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.5ms
# Speed: 2.1ms preprocess, 50.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.7ms
# Speed: 2.1ms preprocess, 49.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.3ms
# Speed: 2.0ms preprocess, 49.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.6ms
# Speed: 2.2ms preprocess, 50.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 51.0ms
# Speed: 1.9ms preprocess, 51.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.9ms
# Speed: 1.8ms preprocess, 48.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.8ms
# Speed: 2.2ms preprocess, 49.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.5ms
# Speed: 2.2ms preprocess, 50.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.9ms
# Speed: 1.8ms preprocess, 48.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.7ms
# Speed: 2.1ms preprocess, 49.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.4ms
# Speed: 2.7ms preprocess, 50.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.8ms
# Speed: 2.1ms preprocess, 48.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.1ms
# Speed: 1.9ms preprocess, 50.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.0ms
# Speed: 1.8ms preprocess, 49.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.6ms
# Speed: 2.3ms preprocess, 49.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 50.3ms
# Speed: 2.4ms preprocess, 50.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.6ms
# Speed: 2.8ms preprocess, 49.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.5ms
# Speed: 2.5ms preprocess, 49.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.8ms
# Speed: 2.1ms preprocess, 49.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.6ms
# Speed: 2.7ms preprocess, 49.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.9ms
# Speed: 2.1ms preprocess, 49.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.5ms
# Speed: 2.3ms preprocess, 49.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 49.9ms
# Speed: 2.9ms preprocess, 49.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Processed video saved to outputs/test.mp4

# %%
from extract_metrics import Get_Pose_Estimation

results = Get_Pose_Estimation(input_video_path = "data/sample_video.mp4", model_size = "l")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l-pose.pt to 'models\yolo11l-pose.pt'...
# 100%|██████████| 50.7M/50.7M [00:01<00:00, 36.0MB/s]
# 0: 640x480 1 person, 106.1ms
# Speed: 3.3ms preprocess, 106.1ms inference, 118.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 31.0ms
# Speed: 3.1ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.8ms
# Speed: 2.1ms preprocess, 30.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 57.6ms
# Speed: 2.2ms preprocess, 57.6ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 33.1ms
# Speed: 2.7ms preprocess, 33.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 31.1ms
# Speed: 2.4ms preprocess, 31.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.6ms
# Speed: 2.0ms preprocess, 28.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.7ms
# Speed: 2.2ms preprocess, 30.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.3ms
# Speed: 2.3ms preprocess, 28.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.1ms
# Speed: 2.3ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 29.7ms
# Speed: 2.2ms preprocess, 29.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.6ms
# Speed: 2.2ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.7ms
# Speed: 1.9ms preprocess, 28.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 36.6ms
# Speed: 2.3ms preprocess, 36.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.1ms
# Speed: 1.9ms preprocess, 27.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 29.3ms
# Speed: 1.9ms preprocess, 29.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 34.2ms
# Speed: 2.2ms preprocess, 34.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.4ms
# Speed: 2.2ms preprocess, 25.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.5ms
# Speed: 2.3ms preprocess, 25.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 48.5ms
# Speed: 2.4ms preprocess, 48.5ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.9ms
# Speed: 2.1ms preprocess, 25.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 35.8ms
# Speed: 2.2ms preprocess, 35.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.3ms
# Speed: 2.3ms preprocess, 25.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.5ms
# Speed: 1.9ms preprocess, 27.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.9ms
# Speed: 1.9ms preprocess, 28.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.0ms
# Speed: 2.1ms preprocess, 26.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 31.5ms
# Speed: 1.9ms preprocess, 31.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.7ms
# Speed: 1.9ms preprocess, 25.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.6ms
# Speed: 1.9ms preprocess, 28.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 29.6ms
# Speed: 1.9ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.3ms
# Speed: 2.2ms preprocess, 28.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.5ms
# Speed: 2.1ms preprocess, 27.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.3ms
# Speed: 2.4ms preprocess, 27.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 40.6ms
# Speed: 2.4ms preprocess, 40.6ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 44.8ms
# Speed: 2.3ms preprocess, 44.8ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 46.4ms
# Speed: 3.0ms preprocess, 46.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 31.7ms
# Speed: 2.3ms preprocess, 31.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.1ms
# Speed: 2.1ms preprocess, 27.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.1ms
# Speed: 2.2ms preprocess, 30.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 31.3ms
# Speed: 1.9ms preprocess, 31.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.8ms
# Speed: 2.1ms preprocess, 30.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 33.7ms
# Speed: 2.3ms preprocess, 33.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.8ms
# Speed: 2.1ms preprocess, 27.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.0ms
# Speed: 2.2ms preprocess, 30.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.7ms
# Speed: 2.1ms preprocess, 27.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.0ms
# Speed: 2.2ms preprocess, 27.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.0ms
# Speed: 2.2ms preprocess, 30.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.9ms
# Speed: 2.1ms preprocess, 25.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.1ms
# Speed: 2.1ms preprocess, 26.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.7ms
# Speed: 1.9ms preprocess, 27.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.2ms
# Speed: 2.3ms preprocess, 30.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.4ms
# Speed: 2.4ms preprocess, 28.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 30.0ms
# Speed: 2.1ms preprocess, 30.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.4ms
# Speed: 2.3ms preprocess, 25.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.8ms
# Speed: 1.9ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 27.1ms
# Speed: 2.3ms preprocess, 27.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.2ms
# Speed: 1.8ms preprocess, 25.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.2ms
# Speed: 1.8ms preprocess, 25.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.1ms
# Speed: 1.9ms preprocess, 26.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.4ms
# Speed: 1.9ms preprocess, 25.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.2ms
# Speed: 1.9ms preprocess, 26.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.8ms
# Speed: 1.8ms preprocess, 25.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.2ms
# Speed: 1.9ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.8ms
# Speed: 1.8ms preprocess, 25.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.0ms
# Speed: 1.9ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.0ms
# Speed: 1.9ms preprocess, 26.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.2ms
# Speed: 1.9ms preprocess, 28.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 28.6ms
# Speed: 2.6ms preprocess, 28.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.5ms
# Speed: 2.1ms preprocess, 25.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.5ms
# Speed: 1.8ms preprocess, 25.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.5ms
# Speed: 1.9ms preprocess, 25.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.6ms
# Speed: 2.1ms preprocess, 25.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.4ms
# Speed: 1.9ms preprocess, 25.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.2ms
# Speed: 1.9ms preprocess, 26.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.4ms
# Speed: 1.8ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.6ms
# Speed: 1.9ms preprocess, 25.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.1ms
# Speed: 2.1ms preprocess, 26.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.6ms
# Speed: 2.1ms preprocess, 25.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 26.1ms
# Speed: 1.8ms preprocess, 26.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
